# %%
import pandas as pd
import seaborn as sns
import utils

# %%
trading_days = 30

# %%
raw_df = utils.download()
df, x = utils.process(df=raw_df, trading_days=trading_days)
utils.test(x=x)
#print(df['volatility'].describe().round(3))
# Out:
# ADF Statistic: -6.457758
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
round(0.068917-0.036442,3)
# Out:
# 0.032

# %%
with sns.axes_style("ticks"):
    ax = sns.histplot(data=df,x="volatility")

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
# autocorrelation
sm.graphics.tsa.plot_acf(df.volatility, lags=50)
plt.show()

# %%
ax = sns.histplot(data=df,x="volatility",)
